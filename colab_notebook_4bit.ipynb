# %% [markdown]
# <a href="https://colab.research.google.com/github/karpe29/saguchee/blob/main/colab_notebook_4bit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xcodec2==0.1.3
# Out:
# Collecting xcodec2==0.1.3
#   Downloading xcodec2-0.1.3-py3-none-any.whl.metadata (4.8 kB)
# Collecting accelerate==1.1.0 (from xcodec2==0.1.3)
#   Downloading accelerate-1.1.0-py3-none-any.whl.metadata (19 kB)
# Collecting aiohappyeyeballs==2.4.0 (from xcodec2==0.1.3)
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiohttp==3.10.5 (from xcodec2==0.1.3)
#   Downloading aiohttp-3.10.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting aiosignal==1.3.1 (from xcodec2==0.1.3)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: annotated-types==0.7.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (0.7.0)
# Collecting antlr4-python3-runtime==4.9.3 (from xcodec2==0.1.3)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting async-timeout==4.0.3 (from xcodec2==0.1.3)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting attrs==24.2.0 (from xcodec2==0.1.3)
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: audioread==3.0.1 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (3.0.1)
# Collecting auraloss==0.4.0 (from xcodec2==0.1.3)
#   Downloading auraloss-0.4.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting blobfile==3.0.0 (from xcodec2==0.1.3)
#   Downloading blobfile-3.0.0-py3-none-any.whl.metadata (15 kB)
# Collecting certifi==2024.8.30 (from xcodec2==0.1.3)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi==1.17.1 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (1.17.1)
# Collecting charset-normalizer==3.3.2 (from xcodec2==0.1.3)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting click==8.1.7 (from xcodec2==0.1.3)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting contourpy==1.3.0 (from xcodec2==0.1.3)
#   Downloading contourpy-1.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (0.12.1)
# Collecting datasets==3.0.1 (from xcodec2==0.1.3)
#   Downloading datasets-3.0.1-py3-none-any.whl.metadata (20 kB)
# Collecting decorator==5.1.1 (from xcodec2==0.1.3)
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting deepspeed==0.15.1 (from xcodec2==0.1.3)
#   Downloading deepspeed-0.15.1.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dill==0.3.8 (from xcodec2==0.1.3)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: docker-pycreds==0.4.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (0.4.0)
# Collecting einops==0.8.0 (from xcodec2==0.1.3)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting einx==0.3.0 (from xcodec2==0.1.3)
#   Downloading einx-0.3.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting exceptiongroup==1.2.2 (from xcodec2==0.1.3)
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting filelock==3.16.1 (from xcodec2==0.1.3)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting fire==0.7.0 (from xcodec2==0.1.3)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fonttools==4.54.1 (from xcodec2==0.1.3)
#   Downloading fonttools-4.54.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.7/163.7 kB 7.8 MB/s eta 0:00:00
# Collecting frozendict==2.4.5 (from xcodec2==0.1.3)
#   Downloading frozendict-2.4.5-py311-none-any.whl.metadata (23 kB)
# Collecting frozenlist==1.4.1 (from xcodec2==0.1.3)
#   Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting fsspec==2024.6.1 (from xcodec2==0.1.3)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: gin-config==0.5.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (0.5.0)
# Collecting gitdb==4.0.11 (from xcodec2==0.1.3)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting GitPython==3.1.43 (from xcodec2==0.1.3)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting hjson==3.1.0 (from xcodec2==0.1.3)
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting huggingface-hub==0.25.1 (from xcodec2==0.1.3)
#   Downloading huggingface_hub-0.25.1-py3-none-any.whl.metadata (13 kB)
# Collecting hydra-core==1.3.2 (from xcodec2==0.1.3)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: idna==3.10 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (3.10)
# Collecting importlib-resources==6.4.5 (from xcodec2==0.1.3)
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: iniconfig==2.0.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (2.0.0)
# Collecting Jinja2==3.1.4 (from xcodec2==0.1.3)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib==1.4.2 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (1.4.2)
# Collecting kiwisolver==1.4.7 (from xcodec2==0.1.3)
#   Downloading kiwisolver-1.4.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: lazy-loader==0.4 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (0.4)
# Requirement already satisfied: librosa==0.10.2.post1 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (0.10.2.post1)
# Collecting lightning-utilities==0.11.7 (from xcodec2==0.1.3)
#   Downloading lightning_utilities-0.11.7-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: llvmlite==0.43.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (0.43.0)
# Collecting lxml==5.3.0 (from xcodec2==0.1.3)
#   Downloading lxml-5.3.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting MarkupSafe==2.1.5 (from xcodec2==0.1.3)
#   Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting matplotlib==3.9.2 (from xcodec2==0.1.3)
#   Downloading matplotlib-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting meson==1.4.0 (from xcodec2==0.1.3)
#   Downloading meson-1.4.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (1.3.0)
# Requirement already satisfied: msgpack==1.1.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (1.1.0)
# Requirement already satisfied: multidict==6.1.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (6.1.0)
# Collecting multiprocess==0.70.16 (from xcodec2==0.1.3)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting networkx==3.2.1 (from xcodec2==0.1.3)
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting ninja==1.11.1.1 (from xcodec2==0.1.3)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: numba==0.60.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (0.60.0)
# Collecting numpy==2.0.2 (from xcodec2==0.1.3)
#   Downloading numpy-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 254.3 kB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from xcodec2==0.1.3)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from xcodec2==0.1.3)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from xcodec2==0.1.3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from xcodec2==0.1.3)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from xcodec2==0.1.3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from xcodec2==0.1.3)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from xcodec2==0.1.3)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from xcodec2==0.1.3)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from xcodec2==0.1.3)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-ml-py==12.560.30 (from xcodec2==0.1.3)
#   Downloading nvidia_ml_py-12.560.30-py3-none-any.whl.metadata (8.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from xcodec2==0.1.3)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.68 (from xcodec2==0.1.3)
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from xcodec2==0.1.3)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting omegaconf==2.3.0 (from xcodec2==0.1.3)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting packaging==24.1 (from xcodec2==0.1.3)
#   Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting pandas==2.2.3 (from xcodec2==0.1.3)
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.5 MB/s eta 0:00:00
# Collecting pesq==0.0.4 (from xcodec2==0.1.3)
#   Downloading pesq-0.0.4.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pillow==10.4.0 (from xcodec2==0.1.3)
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: platformdirs==4.3.6 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (4.3.6)
# Requirement already satisfied: pluggy==1.5.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (1.5.0)
# Requirement already satisfied: pooch==1.8.2 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (1.8.2)
# Collecting protobuf==5.28.2 (from xcodec2==0.1.3)
#   Downloading protobuf-5.28.2-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting psutil==6.0.0 (from xcodec2==0.1.3)
#   Downloading psutil-6.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: py-cpuinfo==9.0.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (9.0.0)
# Collecting pyarrow==17.0.0 (from xcodec2==0.1.3)
#   Downloading pyarrow-17.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: pycparser==2.22 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (2.22)
# Collecting pycryptodomex==3.21.0 (from xcodec2==0.1.3)
#   Downloading pycryptodomex-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting pydantic==2.9.2 (from xcodec2==0.1.3)
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 9.5 MB/s eta 0:00:00
# Collecting pydantic-core==2.23.4 (from xcodec2==0.1.3)
#   Downloading pydantic_core-2.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting pydub==0.25.1 (from xcodec2==0.1.3)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting pyparsing==3.1.4 (from xcodec2==0.1.3)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Collecting pystoi==0.4.1 (from xcodec2==0.1.3)
#   Downloading pystoi-0.4.1-py2.py3-none-any.whl.metadata (4.0 kB)
# Collecting pytest==8.3.3 (from xcodec2==0.1.3)
#   Downloading pytest-8.3.3-py3-none-any.whl.metadata (7.5 kB)
# Collecting python-dateutil==2.9.0.post0 (from xcodec2==0.1.3)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytorch-lightning==2.4.0 (from xcodec2==0.1.3)
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting pytz==2024.2 (from xcodec2==0.1.3)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: PyYAML==6.0.2 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (6.0.2)
# Collecting regex==2024.9.11 (from xcodec2==0.1.3)
#   Downloading regex-2024.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (2.32.3)
# Collecting rotary-embedding-torch==0.8.4 (from xcodec2==0.1.3)
#   Downloading rotary_embedding_torch-0.8.4-py3-none-any.whl.metadata (678 bytes)
# Collecting safetensors==0.4.5 (from xcodec2==0.1.3)
#   Downloading safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting scikit-learn==1.5.2 (from xcodec2==0.1.3)
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: scipy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (1.13.1)
# Requirement already satisfied: sentencepiece==0.2.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (0.2.0)
# Collecting sentry-sdk==2.14.0 (from xcodec2==0.1.3)
#   Downloading sentry_sdk-2.14.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting setproctitle==1.3.3 (from xcodec2==0.1.3)
#   Downloading setproctitle-1.3.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Collecting six==1.16.0 (from xcodec2==0.1.3)
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting smmap==5.0.1 (from xcodec2==0.1.3)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting soundfile==0.12.1 (from xcodec2==0.1.3)
#   Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: soxr==0.5.0.post1 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (0.5.0.post1)
# Collecting sympy==1.13.3 (from xcodec2==0.1.3)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: termcolor==2.5.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (2.5.0)
# Requirement already satisfied: threadpoolctl==3.5.0 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (3.5.0)
# Collecting tiktoken==0.8.0 (from xcodec2==0.1.3)
#   Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting tokenizers==0.20.1 (from xcodec2==0.1.3)
#   Downloading tokenizers-0.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting tomli==2.0.2 (from xcodec2==0.1.3)
#   Downloading tomli-2.0.2-py3-none-any.whl.metadata (10.0 kB)
# Collecting torch==2.4.1 (from xcodec2==0.1.3)
#   Downloading torch-2.4.1-cp311-cp311-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchao==0.5.0 (from xcodec2==0.1.3)
#   Downloading torchao-0.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting torchaudio==2.4.1 (from xcodec2==0.1.3)
#   Downloading torchaudio-2.4.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting torchmetrics==1.4.2 (from xcodec2==0.1.3)
#   Downloading torchmetrics-1.4.2-py3-none-any.whl.metadata (19 kB)
# Collecting torchtune==0.3.1 (from xcodec2==0.1.3)
#   Downloading torchtune-0.3.1-py3-none-any.whl.metadata (19 kB)
# Collecting tqdm==4.66.5 (from xcodec2==0.1.3)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.7 MB/s eta 0:00:00
# Collecting transformers==4.45.2 (from xcodec2==0.1.3)
#   Downloading transformers-4.45.2-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.4 MB/s eta 0:00:00
# Collecting triton==3.0.0 (from xcodec2==0.1.3)
#   Downloading triton-3.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: typing-extensions==4.12.2 in /usr/local/lib/python3.11/dist-packages (from xcodec2==0.1.3) (4.12.2)
# Collecting tzdata==2024.2 (from xcodec2==0.1.3)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting urllib3==2.2.3 (from xcodec2==0.1.3)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting vector-quantize-pytorch==1.17.8 (from xcodec2==0.1.3)
#   Downloading vector_quantize_pytorch-1.17.8-py3-none-any.whl.metadata (26 kB)
# Collecting wandb==0.18.1 (from xcodec2==0.1.3)
#   Downloading wandb-0.18.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting xxhash==3.5.0 (from xcodec2==0.1.3)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl==1.12.1 (from xcodec2==0.1.3)
#   Downloading yarl-1.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 3.3 MB/s eta 0:00:00
# Collecting zipp==3.20.2 (from xcodec2==0.1.3)
#   Downloading zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities==0.11.7->xcodec2==0.1.3) (75.1.0)
# Downloading xcodec2-0.1.3-py3-none-any.whl (30 kB)
# Downloading accelerate-1.1.0-py3-none-any.whl (333 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.2/333.2 kB 22.9 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Downloading aiohttp-3.10.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.8 MB/s eta 0:00:00
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 5.7 MB/s eta 0:00:00
# Downloading auraloss-0.4.0-py3-none-any.whl (16 kB)
# Downloading blobfile-3.0.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 6.0 MB/s eta 0:00:00
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.3/167.3 kB 14.1 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.3/140.3 kB 13.3 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 9.8 MB/s eta 0:00:00
# Downloading contourpy-1.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.2/323.2 kB 25.2 MB/s eta 0:00:00
# Downloading datasets-3.0.1-py3-none-any.whl (471 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 33.9 MB/s eta 0:00:00
# Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.3 MB/s eta 0:00:00
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.6 MB/s eta 0:00:00
# Downloading einx-0.3.0-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 8.7 MB/s eta 0:00:00
# Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading fonttools-4.54.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 102.0 MB/s eta 0:00:00
# Downloading frozendict-2.4.5-py311-none-any.whl (16 kB)
# Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.3/272.3 kB 21.5 MB/s eta 0:00:00
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 12.5 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.2 MB/s eta 0:00:00
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 18.6 MB/s eta 0:00:00
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 5.0 MB/s eta 0:00:00
# Downloading huggingface_hub-0.25.1-py3-none-any.whl (436 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.4/436.4 kB 33.6 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.3 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 11.5 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 69.5 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.7-py3-none-any.whl (26 kB)
# Downloading lxml-5.3.0-cp311-cp311-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 105.4 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading matplotlib-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 111.0 MB/s eta 0:00:00
# Downloading meson-1.4.0-py3-none-any.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.5/935.5 kB 56.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.6 MB/s eta 0:00:00
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.1 MB/s eta 0:00:00
# Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 24.9 MB/s eta 0:00:00
# Downloading numpy-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 97.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 107.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 85.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 41.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 15.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_ml_py-12.560.30-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 64.5 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.4 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.4 MB/s eta 0:00:00
# Downloading packaging-24.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 4.4 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 110.6 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 106.2 MB/s eta 0:00:00
# Downloading protobuf-5.28.2-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 25.8 MB/s eta 0:00:00
# Downloading psutil-6.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.5/290.5 kB 20.7 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 17.3 MB/s eta 0:00:00
# Downloading pycryptodomex-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 88.2 MB/s eta 0:00:00
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.9/434.9 kB 32.4 MB/s eta 0:00:00
# Downloading pydantic_core-2.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 78.8 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 10.1 MB/s eta 0:00:00
# Downloading pystoi-0.4.1-py2.py3-none-any.whl (8.2 kB)
# Downloading pytest-8.3.3-py3-none-any.whl (342 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.3/342.3 kB 29.3 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 20.1 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 46.4 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 36.9 MB/s eta 0:00:00
# Downloading regex-2024.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.8/792.8 kB 44.9 MB/s eta 0:00:00
# Downloading rotary_embedding_torch-0.8.4-py3-none-any.whl (5.6 kB)
# Downloading safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.0/435.0 kB 33.1 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 75.7 MB/s eta 0:00:00
# Downloading sentry_sdk-2.14.0-py2.py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.4/311.4 kB 24.7 MB/s eta 0:00:00
# Downloading setproctitle-1.3.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.6 MB/s eta 0:00:00
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 100.0 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 62.4 MB/s eta 0:00:00
# Downloading tokenizers-0.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 94.7 MB/s eta 0:00:00
# Downloading tomli-2.0.2-py3-none-any.whl (13 kB)
# Downloading torch-2.4.1-cp311-cp311-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 2.1 MB/s eta 0:00:00
# Downloading torchao-0.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.7 MB/s eta 0:00:00
# Downloading torchaudio-2.4.1-cp311-cp311-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 96.6 MB/s eta 0:00:00
# Downloading torchmetrics-1.4.2-py3-none-any.whl (869 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.2/869.2 kB 53.6 MB/s eta 0:00:00
# Downloading torchtune-0.3.1-py3-none-any.whl (596 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.6/596.6 kB 41.4 MB/s eta 0:00:00
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 7.5 MB/s eta 0:00:00
# Downloading transformers-4.45.2-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 91.9 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 6.0 MB/s eta 0:00:00
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 26.3 MB/s eta 0:00:00
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.3/126.3 kB 11.3 MB/s eta 0:00:00
# Downloading vector_quantize_pytorch-1.17.8-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 3.2 MB/s eta 0:00:00
# Downloading wandb-0.18.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 87.9 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.3 MB/s eta 0:00:00
# Downloading yarl-1.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (487 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.9/487.9 kB 32.7 MB/s eta 0:00:00
# Downloading zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Building wheels for collected packages: antlr4-python3-runtime, deepspeed, fire, pesq
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=7f1c7035104e1da8206fe45fef04abaff9964b5738d00e484e568622a4841b5b
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.15.1-py3-none-any.whl size=1483865 sha256=08013a5e01bc899e6fea24c4b387439d9dfb0c109ebe62f714ca85bf52c3cdc8
#   Stored in directory: /root/.cache/pip/wheels/6e/77/1f/c1727c979b4d8a9d0c78c23ab0f996e779b24e36c4fcfe93b3
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=3f4caab0e30b3e024830955f5950d82c0af3ee1889671def88e5578fdb0cdf48
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.4-cp311-cp311-linux_x86_64.whl size=275939 sha256=0c1ae7e26d06e5aba87cb0ceff494755030b3c05c89e0f877c58d0f5766df6fe
#   Stored in directory: /root/.cache/pip/wheels/ae/f1/23/2698d0bf31eec2b2aa50623b5d93b6206c49c7155d0e31345d
# Successfully built antlr4-python3-runtime deepspeed fire pesq
# Installing collected packages: torchao, pytz, pydub, pesq, nvidia-ml-py, ninja, hjson, antlr4-python3-runtime, zipp, yarl, xxhash, urllib3, tzdata, tqdm, tomli, sympy, smmap, six, setproctitle, safetensors, regex, pyparsing, pydantic-core, pycryptodomex, psutil, protobuf, pillow, packaging, omegaconf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, meson, MarkupSafe, lxml, kiwisolver, importlib-resources, fsspec, frozenlist, frozendict, fonttools, fire, filelock, exceptiongroup, einops, dill, decorator, click, charset-normalizer, certifi, attrs, async-timeout, aiohappyeyeballs, triton, soundfile, sentry-sdk, python-dateutil, pytest, pydantic, pyarrow, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, lightning-utilities, Jinja2, hydra-core, gitdb, einx, contourpy, blobfile, aiosignal, tiktoken, scikit-learn, pystoi, pandas, nvidia-cusolver-cu12, matplotlib, huggingface-hub, GitPython, aiohttp, wandb, torch, tokenizers, vector-quantize-pytorch, transformers, torchmetrics, torchaudio, rotary-embedding-torch, deepspeed, datasets, auraloss, accelerate, torchtune, pytorch-lightning, xcodec2
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.1
#     Uninstalling pytz-2025.1:
#       Successfully uninstalled pytz-2025.1
#   Attempting uninstall: nvidia-ml-py
#     Found existing installation: nvidia-ml-py 12.570.86
#     Uninstalling nvidia-ml-py-12.570.86:
#       Successfully uninstalled nvidia-ml-py-12.570.86
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.21.0
#     Uninstalling zipp-3.21.0:
#       Successfully uninstalled zipp-3.21.0
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.18.3
#     Uninstalling yarl-1.18.3:
#       Successfully uninstalled yarl-1.18.3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.1
#     Uninstalling tzdata-2025.1:
#       Successfully uninstalled tzdata-2025.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: smmap
#     Found existing installation: smmap 5.0.2
#     Uninstalling smmap-5.0.2:
#       Successfully uninstalled smmap-5.0.2
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: setproctitle
#     Found existing installation: setproctitle 1.3.5
#     Uninstalling setproctitle-1.3.5:
#       Successfully uninstalled setproctitle-1.3.5
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.5.3
#     Uninstalling safetensors-0.5.3:
#       Successfully uninstalled safetensors-0.5.3
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.11.6
#     Uninstalling regex-2024.11.6:
#       Successfully uninstalled regex-2024.11.6
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.1
#     Uninstalling pyparsing-3.2.1:
#       Successfully uninstalled pyparsing-3.2.1
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.27.2
#     Uninstalling pydantic_core-2.27.2:
#       Successfully uninstalled pydantic_core-2.27.2
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.6
#     Uninstalling protobuf-4.25.6:
#       Successfully uninstalled protobuf-4.25.6
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: lxml
#     Found existing installation: lxml 5.3.1
#     Uninstalling lxml-5.3.1:
#       Successfully uninstalled lxml-5.3.1
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.8
#     Uninstalling kiwisolver-1.4.8:
#       Successfully uninstalled kiwisolver-1.4.8
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib_resources 6.5.2
#     Uninstalling importlib_resources-6.5.2:
#       Successfully uninstalled importlib_resources-6.5.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.5.0
#     Uninstalling frozenlist-1.5.0:
#       Successfully uninstalled frozenlist-1.5.0
#   Attempting uninstall: frozendict
#     Found existing installation: frozendict 2.4.6
#     Uninstalling frozendict-2.4.6:
#       Successfully uninstalled frozendict-2.4.6
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.56.0
#     Uninstalling fonttools-4.56.0:
#       Successfully uninstalled fonttools-4.56.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.17.0
#     Uninstalling filelock-3.17.0:
#       Successfully uninstalled filelock-3.17.0
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.1
#     Uninstalling einops-0.8.1:
#       Successfully uninstalled einops-0.8.1
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: click
#     Found existing installation: click 8.1.8
#     Uninstalling click-8.1.8:
#       Successfully uninstalled click-8.1.8
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.4.1
#     Uninstalling charset-normalizer-3.4.1:
#       Successfully uninstalled charset-normalizer-3.4.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.1.31
#     Uninstalling certifi-2025.1.31:
#       Successfully uninstalled certifi-2025.1.31
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.1.0
#     Uninstalling attrs-25.1.0:
#       Successfully uninstalled attrs-25.1.0
#   Attempting uninstall: aiohappyeyeballs
#     Found existing installation: aiohappyeyeballs 2.4.6
#     Uninstalling aiohappyeyeballs-2.4.6:
#       Successfully uninstalled aiohappyeyeballs-2.4.6
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: soundfile
#     Found existing installation: soundfile 0.13.1
#     Uninstalling soundfile-0.13.1:
#       Successfully uninstalled soundfile-0.13.1
#   Attempting uninstall: sentry-sdk
#     Found existing installation: sentry-sdk 2.22.0
#     Uninstalling sentry-sdk-2.22.0:
#       Successfully uninstalled sentry-sdk-2.22.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: pytest
#     Found existing installation: pytest 8.3.5
#     Uninstalling pytest-8.3.5:
#       Successfully uninstalled pytest-8.3.5
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.6
#     Uninstalling pydantic-2.10.6:
#       Successfully uninstalled pydantic-2.10.6
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 3.1.5
#     Uninstalling Jinja2-3.1.5:
#       Successfully uninstalled Jinja2-3.1.5
#   Attempting uninstall: gitdb
#     Found existing installation: gitdb 4.0.12
#     Uninstalling gitdb-4.0.12:
#       Successfully uninstalled gitdb-4.0.12
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.1
#     Uninstalling contourpy-1.3.1:
#       Successfully uninstalled contourpy-1.3.1
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.3.2
#     Uninstalling aiosignal-1.3.2:
#       Successfully uninstalled aiosignal-1.3.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.28.1
#     Uninstalling huggingface-hub-0.28.1:
#       Successfully uninstalled huggingface-hub-0.28.1
#   Attempting uninstall: GitPython
#     Found existing installation: GitPython 3.1.44
#     Uninstalling GitPython-3.1.44:
#       Successfully uninstalled GitPython-3.1.44
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.13
#     Uninstalling aiohttp-3.11.13:
#       Successfully uninstalled aiohttp-3.11.13
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.19.7
#     Uninstalling wandb-0.19.7:
#       Successfully uninstalled wandb-0.19.7
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu124
#     Uninstalling torch-2.5.1+cu124:
#       Successfully uninstalled torch-2.5.1+cu124
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.5.1+cu124
#     Uninstalling torchaudio-2.5.1+cu124:
#       Successfully uninstalled torchaudio-2.5.1+cu124
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.3.0
#     Uninstalling accelerate-1.3.0:
#       Successfully uninstalled accelerate-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# langchain 0.3.19 requires numpy<2,>=1.26.4; python_version < "3.12", but you have numpy 2.0.2 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.6.1 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.0.2 which is incompatible.
# torchvision 0.20.1+cu124 requires torch==2.5.1, but you have torch 2.4.1 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.0.2 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# pytensor 2.27.1 requires numpy<2,>=1.17.0, but you have numpy 2.0.2 which is incompatible.
# Successfully installed GitPython-3.1.43 Jinja2-3.1.4 MarkupSafe-2.1.5 accelerate-1.1.0 aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiosignal-1.3.1 antlr4-python3-runtime-4.9.3 async-timeout-4.0.3 attrs-24.2.0 auraloss-0.4.0 blobfile-3.0.0 certifi-2024.8.30 charset-normalizer-3.3.2 click-8.1.7 contourpy-1.3.0 datasets-3.0.1 decorator-5.1.1 deepspeed-0.15.1 dill-0.3.8 einops-0.8.0 einx-0.3.0 exceptiongroup-1.2.2 filelock-3.16.1 fire-0.7.0 fonttools-4.54.1 frozendict-2.4.5 frozenlist-1.4.1 fsspec-2024.6.1 gitdb-4.0.11 hjson-3.1.0 huggingface-hub-0.25.1 hydra-core-1.3.2 importlib-resources-6.4.5 kiwisolver-1.4.7 lightning-utilities-0.11.7 lxml-5.3.0 matplotlib-3.9.2 meson-1.4.0 multiprocess-0.70.16 networkx-3.2.1 ninja-1.11.1.1 numpy-2.0.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-ml-py-12.560.30 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 omegaconf-2.3.0 packaging-24.1 pandas-2.2.3 pesq-0.0.4 pillow-10.4.0 protobuf-5.28.2 psutil-6.0.0 pyarrow-17.0.0 pycryptodomex-3.21.0 pydantic-2.9.2 pydantic-core-2.23.4 pydub-0.25.1 pyparsing-3.1.4 pystoi-0.4.1 pytest-8.3.3 python-dateutil-2.9.0.post0 pytorch-lightning-2.4.0 pytz-2024.2 regex-2024.9.11 rotary-embedding-torch-0.8.4 safetensors-0.4.5 scikit-learn-1.5.2 sentry-sdk-2.14.0 setproctitle-1.3.3 six-1.16.0 smmap-5.0.1 soundfile-0.12.1 sympy-1.13.3 tiktoken-0.8.0 tokenizers-0.20.1 tomli-2.0.2 torch-2.4.1 torchao-0.5.0 torchaudio-2.4.1 torchmetrics-1.4.2 torchtune-0.3.1 tqdm-4.66.5 transformers-4.45.2 triton-3.0.0 tzdata-2024.2 urllib3-2.2.3 vector-quantize-pytorch-1.17.8 wandb-0.18.1 xcodec2-0.1.3 xxhash-3.5.0 yarl-1.12.1 zipp-3.20.2

# %%
# !pip install numpy==1.26.4
# !pip install torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 93.4 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xcodec2 0.1.3 requires numpy==2.0.2, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# torchvision 0.20.1+cu124 requires torch==2.5.1, but you have torch 2.4.1 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# Successfully installed numpy-1.26.4
# Collecting torch==2.5.1
#   Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: torchvision==0.20.1 in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Collecting torchaudio==2.5.1
#   Downloading torchaudio-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.5.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.5.1)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.5.1)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (9.1.0.70)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.5.1)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.5.1)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.5.1)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.5.1)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.5.1)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch==2.5.1)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch==2.5.1)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.5.1)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch==2.5.1)
#   Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch==2.5.1)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.20.1) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.20.1) (10.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.5.1) (2.1.5)
# Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 1.7 MB/s eta 0:00:00
# Downloading torchaudio-2.5.1-cp311-cp311-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 40.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 60.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 58.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.0 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.8 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 81.0 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 6.7 MB/s eta 0:00:00
# Installing collected packages: triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cusolver-cu12, torch, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.0.0
#     Uninstalling triton-3.0.0:
#       Successfully uninstalled triton-3.0.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.1.105
#     Uninstalling nvidia-nvtx-cu12-12.1.105:
#       Successfully uninstalled nvidia-nvtx-cu12-12.1.105
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.68
#     Uninstalling nvidia-nvjitlink-cu12-12.6.68:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.68
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.20.5
#     Uninstalling nvidia-nccl-cu12-2.20.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.20.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.2.106
#     Uninstalling nvidia-curand-cu12-10.3.2.106:
#       Successfully uninstalled nvidia-curand-cu12-10.3.2.106
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.0.2.54
#     Uninstalling nvidia-cufft-cu12-11.0.2.54:
#       Successfully uninstalled nvidia-cufft-cu12-11.0.2.54
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.1.105
#     Uninstalling nvidia-cuda-runtime-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.1.105
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.1.105
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.1.105
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.1.105
#     Uninstalling nvidia-cuda-cupti-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.1.105
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.1.3.1
#     Uninstalling nvidia-cublas-cu12-12.1.3.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.1.3.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.1.0.106
#     Uninstalling nvidia-cusparse-cu12-12.1.0.106:
#       Successfully uninstalled nvidia-cusparse-cu12-12.1.0.106
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.4.5.107
#     Uninstalling nvidia-cusolver-cu12-11.4.5.107:
#       Successfully uninstalled nvidia-cusolver-cu12-11.4.5.107
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.1
#     Uninstalling torch-2.4.1:
#       Successfully uninstalled torch-2.4.1
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.4.1
#     Uninstalling torchaudio-2.4.1:
#       Successfully uninstalled torchaudio-2.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xcodec2 0.1.3 requires numpy==2.0.2, but you have numpy 1.26.4 which is incompatible.
# xcodec2 0.1.3 requires nvidia-cublas-cu12==12.1.3.1, but you have nvidia-cublas-cu12 12.4.5.8 which is incompatible.
# xcodec2 0.1.3 requires nvidia-cuda-cupti-cu12==12.1.105, but you have nvidia-cuda-cupti-cu12 12.4.127 which is incompatible.
# xcodec2 0.1.3 requires nvidia-cuda-nvrtc-cu12==12.1.105, but you have nvidia-cuda-nvrtc-cu12 12.4.127 which is incompatible.
# xcodec2 0.1.3 requires nvidia-cuda-runtime-cu12==12.1.105, but you have nvidia-cuda-runtime-cu12 12.4.127 which is incompatible.
# xcodec2 0.1.3 requires nvidia-cufft-cu12==11.0.2.54, but you have nvidia-cufft-cu12 11.2.1.3 which is incompatible.
# xcodec2 0.1.3 requires nvidia-curand-cu12==10.3.2.106, but you have nvidia-curand-cu12 10.3.5.147 which is incompatible.
# xcodec2 0.1.3 requires nvidia-cusolver-cu12==11.4.5.107, but you have nvidia-cusolver-cu12 11.6.1.9 which is incompatible.
# xcodec2 0.1.3 requires nvidia-cusparse-cu12==12.1.0.106, but you have nvidia-cusparse-cu12 12.3.1.170 which is incompatible.
# xcodec2 0.1.3 requires nvidia-nccl-cu12==2.20.5, but you have nvidia-nccl-cu12 2.21.5 which is incompatible.
# xcodec2 0.1.3 requires nvidia-nvjitlink-cu12==12.6.68, but you have nvidia-nvjitlink-cu12 12.4.127 which is incompatible.
# xcodec2 0.1.3 requires nvidia-nvtx-cu12==12.1.105, but you have nvidia-nvtx-cu12 12.4.127 which is incompatible.
# xcodec2 0.1.3 requires sympy==1.13.3, but you have sympy 1.13.1 which is incompatible.
# xcodec2 0.1.3 requires torch==2.4.1, but you have torch 2.5.1 which is incompatible.
# xcodec2 0.1.3 requires torchaudio==2.4.1, but you have torchaudio 2.5.1 which is incompatible.
# xcodec2 0.1.3 requires triton==3.0.0, but you have triton 3.1.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 sympy-1.13.1 torch-2.5.1 torchaudio-2.5.1 triton-3.1.0

# %%
# !pip install bitsandbytes -U
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.5.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (2.1.5)
# Downloading bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 9.4 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.3

# %%
# restart session

# %%
from huggingface_hub import snapshot_download

# %%
# snapshot download faster than normal download since its multiworker
snapshot_download(repo_id="srinivasbilla/llasa-3b", local_dir="/content/srinivasbilla/llasa-3b")
snapshot_download(repo_id="srinivasbilla/xcodec2", local_dir="/content/srinivasbilla/xcodec2")
snapshot_download(repo_id="openai/whisper-large-v3-turbo", local_dir="/content/openai/whisper-large-v3-turbo")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_token.py:90: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.86G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/439 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/930 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/29.5M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/11.7M [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/3.29G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/307 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/63.0 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.62G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.77k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/21.2k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.19k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.71M [00:00<?, ?B/s]
# '/content/openai/whisper-large-v3-turbo'

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline, BitsAndBytesConfig
import torch
import soundfile as sf
from xcodec2.modeling_xcodec2 import XCodec2Model
import torchaudio

quantization_config = BitsAndBytesConfig(load_in_4bit=True)

llasa_3b ='/content/srinivasbilla/llasa-3b'

# be patient this takes a couple mins...
tokenizer = AutoTokenizer.from_pretrained(llasa_3b)

model = AutoModelForCausalLM.from_pretrained(
    llasa_3b,
    trust_remote_code=True,
    device_map='auto',
    quantization_config=quantization_config,
    low_cpu_mem_usage=True
)

model_path = "/content/srinivasbilla/xcodec2"

Codec_model = XCodec2Model.from_pretrained(model_path, low_cpu_mem_usage=True)
Codec_model.eval().cuda()

# whisper_turbo_pipe = pipeline(
#     "automatic-speech-recognition",
#     model="openai/whisper-large-v3-turbo",
#     torch_dtype=torch.float16,
#     device='cuda',
# )
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
def ids_to_speech_tokens(speech_ids):

    speech_tokens_str = []
    for speech_id in speech_ids:
        speech_tokens_str.append(f"<|s_{speech_id}|>")
    return speech_tokens_str

def extract_speech_ids(speech_tokens_str):

    speech_ids = []
    for token_str in speech_tokens_str:
        if token_str.startswith('<|s_') and token_str.endswith('|>'):
            num_str = token_str[4:-2]

            num = int(num_str)
            speech_ids.append(num)
        else:
            print(f"Unexpected token: {token_str}")
    return speech_ids

def infer(sample_audio_path, target_text, prompt_text=None):
    waveform, sample_rate = torchaudio.load(sample_audio_path)
    if len(waveform[0])/sample_rate > 15:
        print("Trimming audio to first 15secs.")
        waveform = waveform[:, :sample_rate*15]

    # Check if the audio is stereo (i.e., has more than one channel)
    if waveform.size(0) > 1:
        # Convert stereo to mono by averaging the channels
        waveform_mono = torch.mean(waveform, dim=0, keepdim=True)
    else:
        # If already mono, just use the original waveform
        waveform_mono = waveform

    prompt_wav = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000)(waveform_mono)

    if prompt_text is None:
        prompt_text = whisper_turbo_pipe(prompt_wav[0].numpy())['text'].strip()

    print(f"Prompt: {prompt_text}")
    print(f"Target: {target_text}")

    if len(target_text) == 0:
        return None
    elif len(target_text) > 300:
        print("Text is too long. Please keep it under 300 characters.")
        target_text = target_text[:300]

    input_text = prompt_text + ' ' + target_text

    #TTS start!
    with torch.no_grad():
        # Encode the prompt wav
        vq_code_prompt = Codec_model.encode_code(input_waveform=prompt_wav)

        vq_code_prompt = vq_code_prompt[0,0,:]
        # Convert int 12345 to token <|s_12345|>
        speech_ids_prefix = ids_to_speech_tokens(vq_code_prompt)

        formatted_text = f"<|TEXT_UNDERSTANDING_START|>{input_text}<|TEXT_UNDERSTANDING_END|>"

        # Tokenize the text and the speech prefix
        chat = [
            {"role": "user", "content": "Convert the text to speech:" + formatted_text},
            {"role": "assistant", "content": "<|SPEECH_GENERATION_START|>" + ''.join(speech_ids_prefix)}
        ]

        input_ids = tokenizer.apply_chat_template(
            chat,
            tokenize=True,
            return_tensors='pt',
            continue_final_message=True
        )
        input_ids = input_ids.to('cuda')
        speech_end_id = tokenizer.convert_tokens_to_ids('<|SPEECH_GENERATION_END|>')

        # Generate the speech autoregressively
        outputs = model.generate(
            input_ids,
            max_length=2048,  # We trained our model with a max length of 2048
            eos_token_id= speech_end_id ,
            do_sample=True,
            top_p=1,
            temperature=0.8
        )
        # Extract the speech tokens
        generated_ids = outputs[0][input_ids.shape[1]-len(speech_ids_prefix):-1]

        speech_tokens = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)

        # Convert  token <|s_23456|> to int 23456
        speech_tokens = extract_speech_ids(speech_tokens)

        speech_tokens = torch.tensor(speech_tokens).cuda().unsqueeze(0).unsqueeze(0)

        # Decode the speech tokens to speech waveform
        gen_wav = Codec_model.decode_code(speech_tokens)

        # if only need the generated part
        gen_wav = gen_wav[:,:,prompt_wav.shape[1]:]

    return gen_wav[0, 0, :].cpu().numpy()

# %%
# samples from https://huggingface.co/datasets/leafspark/openai-voices?row=12

# you must give prompt text if you dont load whisper
prompt_text = "Last September, I received an offer from Sam Altman, who wanted to hire me to voice the current ChatGPT 4.0 system. He told me that he felt that by my voicing the system, I could bridge the gap between tech companies and creatives,"
target_text = "Hi! How can I be of assistance to you today?"
output_audio = infer('/content/sky_sample.wav', target_text , prompt_text=prompt_text)
# Out:
# Prompt: Last September, I received an offer from Sam Altman, who wanted to hire me to voice the current ChatGPT 4.0 system. He told me that he felt that by my voicing the system, I could bridge the gap between tech companies and creatives,
# Target: Hi! How can I be of assistance to you today?
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py:451: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)

# %%
from IPython.display import Audio
Audio(output_audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
